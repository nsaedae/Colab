# %% [markdown]
# <a href="https://colab.research.google.com/github/nsaedae/Colab/blob/main/3_3_%ED%85%90%EC%84%9C%ED%94%8C%EB%A1%9C_%EA%B8%B0%EC%B4%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
날짜 : 2021/02/04
이름 : 김철학
내용 : Tensorflow 기초
"""

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.4.1'

# %%
#텐서플로 상수
var1 = tf.constant('Hello Tensorflow!')
var1.numpy()
# Out:
# b'Hello Tensorflow!'

# %%
#텐서플로 연산
num1 = tf.Variable(1)
num2 = tf.Variable(2)

num3 = num1 + num2
num3.numpy()
# Out:
# 3
