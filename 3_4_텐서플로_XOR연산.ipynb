# %% [markdown]
# <a href="https://colab.research.google.com/github/nsaedae/Colab/blob/main/3_4_%ED%85%90%EC%84%9C%ED%94%8C%EB%A1%9C_XOR%EC%97%B0%EC%82%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
날짜 : 2021/02/04
이름 : 김철학
내용 : 텐서플로 XOR 연산 실습하기
"""

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.losses import mse
tf.__version__
# Out:
# '2.4.1'

# %%
#데이터 준비
data = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
label = np.array([[0], [1], [1], [0]])

# %%
#학습모델 설계
model = Sequential()
model.add(Dense(units=100, input_shape=(2,), activation='sigmoid'))
model.add(Dense(units=1, activation='sigmoid'))

# %%
#모델 설정
model.compile(optimizer='Adam',
              loss=mse,
              metrics=['acc'])

# %%
#학습하기
model.fit(data, label, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 332ms/step - loss: 0.2937 - acc: 0.5000
# Epoch 2/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2889 - acc: 0.5000
# Epoch 3/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2843 - acc: 0.5000
# Epoch 4/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2799 - acc: 0.5000
# Epoch 5/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2758 - acc: 0.5000
# Epoch 6/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2719 - acc: 0.5000
# Epoch 7/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2683 - acc: 0.5000
# Epoch 8/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2651 - acc: 0.5000
# Epoch 9/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2621 - acc: 0.5000
# Epoch 10/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2595 - acc: 0.5000
# Epoch 11/1000
# ...

# %%
#검증하기
result = model.predict(data)
result
# Out:
# array([[0.3974566 ],
#        [0.56163716],
#        [0.56103337],
#        [0.48143357]], dtype=float32)
